# %%
stato = {"Lombardia" : "Milano", 
         "Lazio" : "Roma", 
         "Campania" : "Napoli", 
         "Piemonte" : "Torino",
         "Sicilia" : "Palermo",
         "Puglia" : "Bari",
         "Veneto" : "Venezia",
         "Marche" : "Ancona",
         "Toscana" : "Firenze",
         "Umbria" : "Perugia",
         "Liguria" : "Genova",
         "Emilia Romagna" : "Bologna",
         "Friuli Venezia Giulia" : "Trieste"
        }

# %%
for chiave, valore in stato.items():
    print(f"La capitale della regione {chiave} è {valore}")
# Out:
# La capitale della regione Lombardia è Milano
# La capitale della regione Lazio è Roma
# La capitale della regione Campania è Napoli
# La capitale della regione Piemonte è Torino
# La capitale della regione Sicilia è Palermo
# La capitale della regione Puglia è Bari
# La capitale della regione Veneto è Venezia
# La capitale della regione Marche è Ancona
# La capitale della regione Toscana è Firenze
# La capitale della regione Umbria è Perugia
# La capitale della regione Liguria è Genova
# La capitale della regione Emilia Romagna è Bologna
# La capitale della regione Friuli Venezia Giulia è Trieste

# %%
for regione, capitale in stato.items():
    print(regione, "-", capitale)
# Out:
# Lombardia - Milano
# Lazio - Roma
# Campania - Napoli
# Piemonte - Torino
# Sicilia - Palermo
# Puglia - Bari
# Veneto - Venezia
# Marche - Ancona
# Toscana - Firenze
# Umbria - Perugia
# Liguria - Genova
# Emilia Romagna - Bologna
# Friuli Venezia Giulia - Trieste

# %%
regione = input("Inserisci una regione: ")
capitale = stato.get(regione, "Regione non presente nel dizionario")
print("La capitale è:", capitale)
# Out:
# La capitale è: Firenze

# %%
print(stato.keys())
# Out:
# dict_keys(['Lombardia', 'Lazio', 'Campania', 'Piemonte', 'Sicilia', 'Puglia', 'Veneto', 'Marche', 'Toscana', 'Umbria', 'Liguria', 'Emilia Romagna', 'Friuli Venezia Giulia'])

# %%
stato.update({"Sicilia": "poo"})

# %%
# pip install -U ipykernel
print(stato.values())
# Out:
# dict_values(['Milano', 'Roma', 'Napoli', 'Torino', 'poo', 'Bari', 'Venezia', 'Ancona', 'Firenze', 'Perugia', 'Genova', 'Bologna', 'Trieste'])

# %%
stato.pop("Sicilia")
# Out:
# 'poo'

# %%
print(stato.values())
# Out:
# dict_values(['Milano', 'Roma', 'Napoli', 'Torino', 'Bari', 'Venezia', 'Ancona', 'Firenze', 'Perugia', 'Genova', 'Bologna', 'Trieste'])

# %%
matrice2d = [
    [1,2,3],
    [4,5,6],
    [7,8,9]
]

print(matrice2d)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
print(matrice2d[1][2])
# Out:
# 6

# %%
array3d = [
    [
        [1,2],
        [3,4]
    ],
    [
        [5,6],
        [7,8]
    ]
]

print(array3d)
# Out:
# [[[1, 2], [3, 4]], [[5, 6], [7, 8]]]

# %%
print(array3d[0][1][1])
# Out:
# 4

# %%
for numero in range(10):
    if numero % 2 == 0:
        continue
    if numero == 7:
        break
    print(numero)
# Out:
# 1
# 3
# 5
