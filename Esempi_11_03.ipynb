# %% [markdown]
# <h1>Parametri comuni in Pandas / Matplotlib</h1>
#
#
# | Parametro           | Dove si usa                                                      | Significato                                           | Esempio                                                                 |
# | ------------------- | ---------------------------------------------------------------- | ----------------------------------------------------- | ----------------------------------------------------------------------- |
# | `kind`              | `df.plot()`                                                      | Tipo di grafico                                       | `"bar"`, `"line"`, `"hist"`, `"pie"`                                    |
# | `x`                 | `df.plot()`                                                      | Colonna da usare per asse X                           | `x="nome"`                                                              |
# | `y`                 | `df.plot()`                                                      | Colonna da usare per asse Y                           | `y="voto"`                                                              |
# | `color`             | `df.plot()` o matplotlib                                         | Colore barre o linee                                  | `color="orange"`                                                        |
# | `figsize`           | `df.plot()` o matplotlib                                         | Dimensione grafico in pollici                         | `figsize=(10,6)`                                                        |
# | `autopct`           | `plot(kind="pie")`                                               | Mostra percentuale sulle fette della torta            | `autopct='%1.1f%%'` → 1 cifra decimale, con `%`                         |
# | `startangle`        | `plot(kind="pie")`                                               | Rotazione iniziale della torta in gradi               | `startangle=90` → inizia dall’alto                                      |
# | `inplace`           | Funzioni DataFrame (`fillna()`, `drop_duplicates()`, `rename()`) | Modifica il DataFrame direttamente senza creare copia | `df.drop_duplicates(inplace=True)`                                      |
# | `ascending`         | `sort_values()`                                                  | Ordina crescente o decrescente                        | `df.sort_values("voto", ascending=False)` → decrescente                 |
# | `bins`              | `plot(kind="hist")`                                              | Numero di intervalli per istogramma                   | `df["voto"].plot(kind="hist", bins=5)`                                  |
# | `edgecolor`         | `plot(kind="hist")`                                              | Colore contorno barre istogramma                      | `edgecolor="black"`                                                     |
# | `ylabel`            | matplotlib                                                       | Etichetta asse Y                                      | `plt.ylabel("Voto")`                                                    |
# | `xlabel`            | matplotlib                                                       | Etichetta asse X                                      | `plt.xlabel("Studente")`                                                |
# | `title`             | matplotlib                                                       | Titolo grafico                                        | `plt.title("Voti studenti")`                                            |
# | `groupby()`         | DataFrame                                                        | Raggruppa dati per colonna                            | `df.groupby("corso")["voto"].mean()`                                    |
# | `apply()`           | DataFrame / Serie                                                | Applica funzione a ogni elemento                      | `df["esito"] = df["voto"].apply(lambda x: "Pass" if x>=27 else "Fail")` |
# | `value_counts()`    | Serie                                                            | Conta quante volte compare ciascun valore             | `df["corso"].value_counts()`                                            |
# | `reset_index()`     | DataFrame                                                        | Ricostruisce indice dopo `groupby` o ordinamento      | `df.groupby("corso")["voto"].max().reset_index()`                       |
# | `fillna()`          | DataFrame / Serie                                                | Riempie valori mancanti                               | `df["voto"].fillna(df["voto"].mean(), inplace=True)`                    |
# | `dropna()`          | DataFrame / Serie                                                | Elimina righe con valori mancanti                     | `df.dropna(inplace=True)`                                               |
# | `drop_duplicates()` | DataFrame                                                        | Elimina righe duplicate                               | `df.drop_duplicates(inplace=True)`                                      |
# | `astype()`          | DataFrame / Serie                                                | Cambia tipo di dati colonna                           | `df["voto"] = df["voto"].astype(int)`                                   |
# | `head()`            | DataFrame                                                        | Mostra prime N righe                                  | `df.head(5)`                                                            |
# | `tail()`            | DataFrame                                                        | Mostra ultime N righe                                 | `df.tail(5)`                                                            |
# | `mean()`            | Serie                                                            | Calcola media                                         | `df["voto"].mean()`                                                     |
# | `max()`             | Serie / DataFrame                                                | Calcola massimo                                       | `df["voto"].max()`                                                      |
# | `min()`             | Serie / DataFrame                                                | Calcola minimo                                        | `df["voto"].min()`                                                      |

# %% [markdown]
# <h3>Istallazione di pandas e matplotlib</h3>
#
# <p>pip install pandas matplotlib</p>

# %%
pip install pandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# <h1>Lezione – Grafici in Jupyter Notebook</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Creare il dataset

# %%
studenti = [
    {"id":1, "nome":"Marco", "cognome":"Rossi", "classe":"3A", "voto":8},
    {"id":2, "nome":"Anna", "cognome":"Bianchi", "classe":"2B", "voto":9},
    {"id":3, "nome":"Luca", "cognome":"Verdi", "classe":"4A", "voto":7}
]

# %% [markdown]
# Trasforma i dati in DataFrame

# %%
import pandas as pd

df_studenti = pd.DataFrame(studenti)

print(df_studenti)
# Out:
#    id   nome  cognome classe  voto
# 0   1  Marco    Rossi     3A     8
# 1   2   Anna  Bianchi     2B     9
# 2   3   Luca    Verdi     4A     7

# %% [markdown]
# Salvare i dati in un file CSV

# %%
df_studenti.to_csv("studenti.csv", index=False)
df_studenti
# Out:
#    id   nome  cognome classe  voto
# 0   1  Marco    Rossi     3A     8
# 1   2   Anna  Bianchi     2B     9
# 2   3   Luca    Verdi     4A     7

# %% [markdown]
# Grafica a barra degli studenti

# %%
df_studenti.plot(x="nome", y="voto", kind="bar")
plt.show()

# %%
df_studenti.plot(x="nome", y="voto", kind="barh")
plt.show()

# %%
import pandas as pd
df = pd.read_csv("studente.csv")

df
# Out:
#     id        nome  eta             corso  voto
# 0    1       Marco   22            Python    28
# 1    2        Anna   21            Python    30
# 2    3        Luca   23     Data Analysis    27
# 3    4        Sara   20            Python    25
# 4    5      Giulia   24     Data Analysis    29
# 5    6       Paolo   22            Python    26
# 6    7   Francesca   23  Machine Learning    30
# 7    8      Matteo   21            Python    24
# 8    9       Elena   22     Data Analysis    28
# 9   10      Simone   25  Machine Learning    27
# 10  11       Maria   22            Python    29
# 11  12  Alessandro   24     Data Analysis    26
# 12  13   Valentina   21            Python    27
# 13  14     Stefano   23  Machine Learning    28
# 14  15      Chiara   22     Data Analysis    30
# 15  16     Tommaso   24            Python    25
# 16  17    Beatrice   21  Machine Learning    29
# 17  18    Giovanni   23     Data Analysis    28
# 18  19       Elisa   22            Python    27
# ...

# %%
df.plot(x="nome", y="voto", kind="pie")

plt.show()

# %% [markdown]
# <h3> Create la lista dei materia</h3>
# materiaid, nome

# %%
materie = [
    {"materiaId": 1, "nome": "Matematica"},
    {"materiaId": 2, "nome": "Italiano"},
    {"materiaId": 3, "nome": "Informatica"},
    {"materiaId": 4, "nome": "Storia"},
    {"materiaId": 5, "nome": "Geografia"},
    {"materiaId": 6, "nome": "Fisica"},
    {"materiaId": 7, "nome": "Chimica"},
    {"materiaId": 8, "nome": "Inglese"},
    {"materiaId": 9, "nome": "Arte"},
    {"materiaId": 10, "nome": "Musica"},
    {"materiaId": 11, "nome": "Educazione Fisica"},
    {"materiaId": 12, "nome": "Filosofia"},
    {"materiaId": 13, "nome": "Economia"},
    {"materiaId": 14, "nome": "Diritto"},
    {"materiaId": 15, "nome": "Tecnologia"}
]

materie
# Out:
# [{'materiaId': 1, 'nome': 'Matematica'},
#  {'materiaId': 2, 'nome': 'Italiano'},
#  {'materiaId': 3, 'nome': 'Informatica'},
#  {'materiaId': 4, 'nome': 'Storia'},
#  {'materiaId': 5, 'nome': 'Geografia'},
#  {'materiaId': 6, 'nome': 'Fisica'},
#  {'materiaId': 7, 'nome': 'Chimica'},
#  {'materiaId': 8, 'nome': 'Inglese'},
#  {'materiaId': 9, 'nome': 'Arte'},
#  {'materiaId': 10, 'nome': 'Musica'},
#  {'materiaId': 11, 'nome': 'Educazione Fisica'},
#  {'materiaId': 12, 'nome': 'Filosofia'},
#  {'materiaId': 13, 'nome': 'Economia'},
#  {'materiaId': 14, 'nome': 'Diritto'},
#  {'materiaId': 15, 'nome': 'Tecnologia'}]

# %% [markdown]
# <h3>Creare la lista dei docenti</h3>
# Docenteid, nome, cognome, materiaid, email, Telefono

# %%
docenti = [
    {"docenteId": 1, "nome": "Giovanni", "cognome": "Rossi", "materiaId": 1, "email": "rossi@scuola.it", "telefono": "333111111"},
    {"docenteId": 2, "nome": "Maria", "cognome": "Bianchi", "materiaId": 2, "email": "bianchi@scuola.it", "telefono": "333222222"},
    {"docenteId": 3, "nome": "Luca", "cognome": "Verdi", "materiaId": 3, "email": "verdi@scuola.it", "telefono": "333333333"},
    {"docenteId": 4, "nome": "Anna", "cognome": "Neri", "materiaId": 4, "email": "neri@scuola.it", "telefono": "333444444"},
    {"docenteId": 5, "nome": "Paolo", "cognome": "Ferrari", "materiaId": 5, "email": "ferrari@scuola.it", "telefono": "333555555"},
    {"docenteId": 6, "nome": "Elena", "cognome": "Russo", "materiaId": 6, "email": "russo@scuola.it", "telefono": "333666666"},
    {"docenteId": 7, "nome": "Marco", "cognome": "Riva", "materiaId": 7, "email": "riva@scuola.it", "telefono": "333777777"},
    {"docenteId": 8, "nome": "Laura", "cognome": "Moretti", "materiaId": 8, "email": "moretti@scuola.it", "telefono": "333888888"},
    {"docenteId": 9, "nome": "Stefano", "cognome": "Romano", "materiaId": 9, "email": "romano@scuola.it", "telefono": "333999999"},
    {"docenteId": 10, "nome": "Chiara", "cognome": "Conti", "materiaId": 10, "email": "conti@scuola.it", "telefono": "333101010"},
    {"docenteId": 11, "nome": "Davide", "cognome": "Galli", "materiaId": 11, "email": "galli@scuola.it", "telefono": "333202020"},
    {"docenteId": 12, "nome": "Francesca", "cognome": "Costa", "materiaId": 12, "email": "costa@scuola.it", "telefono": "333303030"},
    {"docenteId": 13, "nome": "Simone", "cognome": "Martini", "materiaId": 13, "email": "martini@scuola.it", "telefono": "333404040"},
    {"docenteId": 14, "nome": "Sara", "cognome": "Greco", "materiaId": 14, "email": "greco@scuola.it", "telefono": "333505050"},
    {"docenteId": 15, "nome": "Alessio", "cognome": "Fontana", "materiaId": 15, "email": "fontana@scuola.it", "telefono": "333606060"}
]

docenti
# Out:
# [{'docenteId': 1,
#   'nome': 'Giovanni',
#   'cognome': 'Rossi',
#   'materiaId': 1,
#   'email': 'rossi@scuola.it',
#   'telefono': '333111111'},
#  {'docenteId': 2,
#   'nome': 'Maria',
#   'cognome': 'Bianchi',
#   'materiaId': 2,
#   'email': 'bianchi@scuola.it',
#   'telefono': '333222222'},
#  {'docenteId': 3,
#   'nome': 'Luca',
#   'cognome': 'Verdi',
#   'materiaId': 3,
#   'email': 'verdi@scuola.it',
#   'telefono': '333333333'},
#  {'docenteId': 4,
#   'nome': 'Anna',
#   'cognome': 'Neri',
#   'materiaId': 4,
#   'email': 'neri@scuola.it',
#   'telefono': '333444444'},
#  {'docenteId': 5,
#   'nome': 'Paolo',
#   'cognome': 'Ferrari',
#   'materiaId': 5,
#   'email': 'ferrari@scuola.it',
#   'telefono': '333555555'},
#  {'docenteId': 6,
#   'nome': 'Elena',
#   'cognome': 'Russo',
#   'materiaId': 6,
#   'email': 'russo@scuola.it',
#   'telefono': '333666666'},
#  {'docenteId': 7,
#   'nome': 'Marco',
#   'cognome': 'Riva',
#   'materiaId': 7,
# ...

# %% [markdown]
# <h3>Creare La lista dei voti</h3>
# votoId, StudenteId, MateriaId, Voto

# %%
# select * from Materia m inner join voti v on m.materiaId = v.materiaId


voti = [
    {"votoId": 1, "studenteId": 1, "materiaId": 1, "voto": 8},
    {"votoId": 2, "studenteId": 2, "materiaId": 2, "voto": 7},
    {"votoId": 3, "studenteId": 3, "materiaId": 3, "voto": 9},
    {"votoId": 4, "studenteId": 4, "materiaId": 4, "voto": 6},
    {"votoId": 5, "studenteId": 5, "materiaId": 5, "voto": 8},
    {"votoId": 6, "studenteId": 6, "materiaId": 6, "voto": 7},
    {"votoId": 7, "studenteId": 7, "materiaId": 7, "voto": 9},
    {"votoId": 8, "studenteId": 8, "materiaId": 8, "voto": 10},
    {"votoId": 9, "studenteId": 9, "materiaId": 9, "voto": 6},
    {"votoId": 10, "studenteId": 10, "materiaId": 10, "voto": 8},
    {"votoId": 11, "studenteId": 11, "materiaId": 11, "voto": 7},
    {"votoId": 12, "studenteId": 12, "materiaId": 12, "voto": 9},
    {"votoId": 13, "studenteId": 13, "materiaId": 13, "voto": 8},
    {"votoId": 14, "studenteId": 14, "materiaId": 14, "voto": 7},
    {"votoId": 15, "studenteId": 15, "materiaId": 15, "voto": 10}
]

voti
# Out:
# [{'votoId': 1, 'studenteId': 1, 'materiaId': 1, 'voto': 8},
#  {'votoId': 2, 'studenteId': 2, 'materiaId': 2, 'voto': 7},
#  {'votoId': 3, 'studenteId': 3, 'materiaId': 3, 'voto': 9},
#  {'votoId': 4, 'studenteId': 4, 'materiaId': 4, 'voto': 6},
#  {'votoId': 5, 'studenteId': 5, 'materiaId': 5, 'voto': 8},
#  {'votoId': 6, 'studenteId': 6, 'materiaId': 6, 'voto': 7},
#  {'votoId': 7, 'studenteId': 7, 'materiaId': 7, 'voto': 9},
#  {'votoId': 8, 'studenteId': 8, 'materiaId': 8, 'voto': 10},
#  {'votoId': 9, 'studenteId': 9, 'materiaId': 9, 'voto': 6},
#  {'votoId': 10, 'studenteId': 10, 'materiaId': 10, 'voto': 8},
#  {'votoId': 11, 'studenteId': 11, 'materiaId': 11, 'voto': 7},
#  {'votoId': 12, 'studenteId': 12, 'materiaId': 12, 'voto': 9},
#  {'votoId': 13, 'studenteId': 13, 'materiaId': 13, 'voto': 8},
#  {'votoId': 14, 'studenteId': 14, 'materiaId': 14, 'voto': 7},
#  {'votoId': 15, 'studenteId': 15, 'materiaId': 15, 'voto': 10}]

# %% [markdown]
# ### Trasformiamo in DataFrame

# %%
import pandas as pd # Importazione di pandas

df_materie = pd.DataFrame(materie)
df_docenti = pd.DataFrame(docenti)
df_voti = pd.DataFrame(voti)

# %% [markdown]
# ### Salviamo in CSV

# %%
df_materie.to_csv("materie.csv", index=False)
df_docenti.to_csv("docenti.csv", index=False)
df_voti.to_csv("voti.csv", index=False)

# %% [markdown]
# ### Grafico a barre
# Media voti per materia

# %%
import pandas as pd
import matplotlib.pyplot as plt


materie = pd.read_csv("materie.csv")
docenti = pd.read_csv("docenti.csv")
voti = pd.read_csv("voti.csv")

# %%
media_materia = voti.groupby("materiaId")["voto"].mean()
media_materia
# Out:
# materiaId
# 1      8.0
# 2      7.0
# 3      9.0
# 4      6.0
# 5      8.0
# 6      7.0
# 7      9.0
# 8     10.0
# 9      6.0
# 10     8.0
# 11     7.0
# 12     9.0
# 13     8.0
# 14     7.0
# 15    10.0
# Name: voto, dtype: float64

# %%
media_materia.plot(kind='line', marker='o')

plt.title("Media dei voti per materia")
plt.xlabel("Materia")
plt.ylabel("Media Voti")
plt.show()

# %%
voti["voto"].plot(kind="hist")
plt.title("Distribuzioni dei voti")
plt.xlabel("voto")
plt.ylabel("Numero studenti")
plt.show()

# %% [markdown]
# Andatura dei voti (Grafico a Linee)

# %%
media_materia.plot(kind="line", marker="")

plt.title("Andamento media voti")

plt.xlabel("Materia")

plt.ylabel("Media voto")

plt.show()

# %% [markdown]
# Grafica a Torta
# Distribuzione dei voti

# %%
conteggio_voti = voti["voto"].value_counts()

conteggio_voti.plot(kind="pie", autopct="%1.1f%%")

plt.title("Distribuzione voti")
plt.xlabel("Voti")
plt.ylabel("Percentuali")


plt.show()
voti
# Out:
#     votoId  studenteId  materiaId  voto
# 0        1           1          1     8
# 1        2           2          2     7
# 2        3           3          3     9
# 3        4           4          4     6
# 4        5           5          5     8
# 5        6           6          6     7
# 6        7           7          7     9
# 7        8           8          8    10
# 8        9           9          9     6
# 9       10          10         10     8
# 10      11          11         11     7
# 11      12          12         12     9
# 12      13          13         13     8
# 13      14          14         14     7
# 14      15          15         15    10

# %% [markdown]
# ## Esercizio 1
# ##### Creare un istogramma dei voti.
#
# ## Esercizio 2
# ##### Creare un grafico a barre della media voti per materia.
#
# ## Esercizio 3
# ##### Creare un grafico a torta dei voti.
